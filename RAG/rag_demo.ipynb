# %% [markdown]
# # RAG -- Retrieval Augmented Generation
#
# RAG is needed because large language models don’t have access to up-to-date or private information and can hallucinate when they lack facts. By retrieving relevant documents at query time and grounding the generation on them, RAG makes answers more accurate.

# %% [markdown]
# ### I. Data Indexing
# 1. Divide Documents into chunks
# 2. Split documents into text chunks
# 3. Vectorize text chunks and store in vector database
#
# ---
#
# ### II. Data Retrieval & Generation
#
# 1. Vectorize the user query
# 2. Find Top-K Chunks
# 3. Send user query and Top-K Chunks result to auto-regressive LLM
# 4. Obtain response

# %% [markdown]
# ![RAG flow](https://miro.medium.com/v2/resize:fit:1400/format:webp/1*FhMJ8OE_PoeOyeAavYjzlw.png)

# %%
import os
import glob
import tiktoken
import numpy as np
import gradio as gr
from dotenv import load_dotenv
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.messages import SystemMessage, HumanMessage

# %%
MODEL = "gpt-4.1-nano"
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %% [markdown]
# ## Parse the PDF files

# %%
import fitz  # PyMuPDF

# 分開解析兩個 PDF
with fitz.open("ImageXpress Nano User Guide.pdf") as nano_pdf:
    text_nano = ""
    for page in nano_pdf:
        text_nano += page.get_text("text") + "\n"

with fitz.open("MetaXpress Image Acquisition Guide v5.0.pdf") as metaxpress_pdf:
    text_meta = ""
    for page in metaxpress_pdf:
        text_meta += page.get_text("text") + "\n"

print(f"Nano guide: {len(text_nano):,} chars")
print(f"MetaXpress guide: {len(text_meta):,} chars")
# Out:
# Nano guide: 241,196 chars
# MetaXpress guide: 92,342 chars

# %%
print(text_meta[5000:6000])
# Out:
#  . . . . . . . . . . . . . . . . . 78
#
# 5020933 A
# 5
# 1
# Introduction
# The MetaXpress® High Content Image Acquisition & Analysis Software
# is divided into two major parts:
# •
# Acquisition, which involves configuring settings, acquiring
# images, and storing plate data in a database. For information
# about image acquisition, see the user guide for the
# ImageXpress® Micro Widefield High Content Screening System
# or the ImageXpress® Ultra Confocal High Content Screening
# System. Both user guides are provided on the MetaXpress
# Software installation media and are available in the Molecular
# Devices knowledge base at
# http://www.moleculardevices.com/support.html.
# •
# Analysis, which consists of selecting, measuring, assessing, and
# managing acquired images and plate data.
# This manual describes the general analysis workflow:
#
# Introduction
# 6
# 5020933 A
# Obtaining Support
# Molecular Devices provides a wide range of support for the MetaXpress
# Software:
# 1.
# Documentation — Check the manuals that are incl

# %% [markdown]
# ## Divide Documents into chunks

# %%
encoding = tiktoken.encoding_for_model(MODEL)
tokens = encoding.encode(text_nano)
token_count = len(tokens)
print(f"Total tokens for {MODEL}: {token_count:,}")
# Out:
# Total tokens for gpt-4.1-nano: 52,933

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

chunks = splitter.create_documents(
    texts=[text_nano, text_meta],
    metadatas=[
        {"source": "ImageXpress Nano User Guide"},
        {"source": "MetaXpress Image Acquisition Guide"}
    ]
)

print(f"Total chunks: {len(chunks)}")
print(f"First chunk source: {chunks[0].metadata['source']}")
print(f"First chunk content:\n{chunks[0].page_content[:200]}")
# Out:
# Total chunks: 480
# First chunk source: ImageXpress Nano User Guide
# First chunk content:
# 5058342 B
# October 2017
# ImageXpress® Nano
# Automated Imaging System
# With MetaXpress Software
# User Guide

# %% [markdown]
# ## Vectorize chunks and store in the vector DB (Chroma)
#
# Vectorizing text chunks in RAG so both queries and documents live in the same semantic space, allowing us to efficiently find chunks that are meaningfully similar rather than just keyword-matched.

# %%
import shutil

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

db_name = "nano_manual_chroma_db"

if os.path.exists(db_name):
    shutil.rmtree(db_name)

# 使用 from_documents 保留 metadata
vector_store = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_model,
    persist_directory=db_name
)

print(f"Vector store created with {vector_store._collection.count()} documents")
# Out:
# Vector store created with 480 documents

# %%
collection = vector_store._collection
sample_embedding = collection.get(limit=1, include=["embeddings"])["embeddings"][0]
dimensions = len(sample_embedding)
print(f"Embedding dimensions for the all-MiniLM-L6-v2 model: {dimensions}")
# Out:
# Embedding dimensions for the all-MiniLM-L6-v2 model: 384

# %% [markdown]
# # Data Retrieval & Generation

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(temperature=0, model_name=MODEL)

# %%
from IPython.display import display, Markdown

# %%
# Try a query without vector retrieval
Markdown(llm.invoke(
    "Explain how MetaXpress software obtain z-series 2D projection Image."
).content)
# Out:
# MetaXpress software obtains z-series 2D projection images through a process called z-stack imaging combined with image projection techniques. Here's an overview of how this process works:
#
# 1. **Acquisition of Z-Stack Images:**
#    - The software controls a microscope equipped with a motorized stage and a focus drive.
#    - It captures a series of 2D images (slices) at different focal depths along the z-axis, creating a z-stack. Each slice corresponds to a specific z-position within the sample.
#
# 2. **Image Processing and Alignment:**
#    - The individual z-slices are processed to correct for any drift or misalignment.
#    - This ensures that the images are properly registered for accurate projection.
#
# 3. **Projection to 2D:**
#    - The z-stack images are combined into a single 2D projection image.
#    - MetaXpress offers various projection methods, such as:
#      - **Maximum Intensity Projection (MIP):** Takes the brightest pixel value from each stack position, highlighting the most intense features.
#      - **Average Intensity Projection:** Computes the average pixel value across all slices.
#      - **Sum Projection:** Adds pixel values across slices, useful for quantifying total signal.
#    - The choice of projection method depends on the specific imaging goal.
#
# 4. **Generation of the Z-Projection Image:**
#    - The software processes the selected projection method to produce a single 2D image that summarizes the 3D information contained in the z-stack.
#    - This projection facilitates easier analysis and visualization of structures within the sample.
#
# **In summary:** MetaXpress software acquires a series of images at different depths (z-stack), then applies a projection algorithm (like maximum intensity projection) to generate a 2D image that represents the combined information from the entire z-series. This approach allows researchers to analyze complex 3D structures in a simplified 2D format.

# %%
# Now try with retrieval
retriever = vector_store.as_retriever(search_kwargs={"k": 10})
retriever.invoke("Explain how MetaXpress software obtain z-series 2D projection Image.")
# Out:
# [Document(id='ae0e7758-2ca6-40a7-ae33-9bc482101e74', metadata={'source': 'ImageXpress Nano User Guide'}, page_content='2D\nProjection\nImage\nAvailable for all Z Series acquisition options other than Single Plane indicates how\nthe resulting 2D projection image is generated.\nBest Focus is the default value. The MetaXpress Software estimates the regions\nof best focus in the image stack to within one-tenth pixel accuracy along the Z\naxis. Two resolution grid sizes are used to enhance the criterion of focus through\nthe stack.\nMaximum is recommended only for fluorescence. For each corresponding pixel\nposition in the images, the pixel that has the highest intensity value out of all the\nplanes is determined, and this is the value that is output to the resulting image.\nMinimum is recommended only for transmitted light. For each corresponding\npixel position in the images, the pixel that has the lowest intensity value out of all\nthe planes is determined, and this is the value that is output to the resulting\nimage.\nSum is the intensities of the pixels in the stack planes are added for each'),
#  Document(id='509f297d-474a-4d31-b91d-2aebd2c612df', metadata={'source': 'ImageXpress Nano User Guide'}, page_content='ImageXpress Nano System with MetaXpress Software User Guide\n96\n5058342 B\n2. Configure the Z series acquisition options.\nOption\nDescription\n# of Steps\nThe number of planes at a given site or well position for which images are to\nbe taken. For example, if set to 12, which is the default value, then 12 images\nwill be taken along the Z axis of the sample. You can do the following to adjust\nthis value:\n–Manually type a value in the field.\n–Click the Up or Down arrows in the field.\n–Drag the slider bar that is displayed below the field.\nStep Size\nThe distance in µm between the image planes in the Z series. You can do the\nfollowing to adjust this value:\n–Manually type a value in the field.\n–Click the Up or Down arrows in the field.\n–Drag the slider bar that is displayed below the field.\nNote: Based on the numerical aperture (NA) setting for the objective, the\nMetaXpress Software automatically calculates a recommended Step Size that'),
#  Document(id='915c7bb0-8456-49d7-9031-0c973142ea3e', metadata={'source': 'ImageXpress Nano User Guide'}, page_content='ImageXpress Nano System with MetaXpress Software User Guide\n104\n5058342 B\n3. Click Analysis.\nNote: The options that are displayed on the Analysis tab depend on the series\nacquisition mode (Acquire Time Series or Acquire Z Series) that is selected on the\nAcquisition tab as well as the image that is to be acquired and retained: Single\nplane, 2D Projection Image Only, or Z Series and Projection Image.\nFigure 5-30: Plate Acquisition Setup dialog: Configure tab, Analysis tab (Time Series)'),
#  Document(id='305655db-60b4-4d23-9bae-21b5d9208c69', metadata={'source': 'ImageXpress Nano User Guide'}, page_content='Note: Based on the numerical aperture (NA) setting for the objective, the\nMetaXpress Software automatically calculates a recommended Step Size that\nwould provide the best detail for your Z series. You can click this\nRecommended Step Size message to automatically set the Step Size to this\nrecommended value.\nNote: As you adjust one or both of these values, then the MetaXpress Software automatically\ncalculates the Range, which is the overall image depth from top to bottom of the image sample,\nand displays this value below the Step Size on the tab.\nTable 5-7: Z series acquisition options'),
#  Document(id='563d5ff0-e348-430a-a1d9-e685dd38157b', metadata={'source': 'ImageXpress Nano User Guide'}, page_content='Chapter 5: Configuring Plate Acquisition Options\n5058342 B\n87\nOptions\nDescription\nAcquire Z\nSeries\nenables Z\nSeries\nSingle plane acquires only a single plane based on the autofocus options for the\nselected wavelength, just as if the Acquire Z Series option were disabled. It is\nused in a multi-wavelength acquisition when the Z Series acquisition is not\nrequired for the selected wavelength.\n2D Projection Image Only acquires the Z Series, and a single projection image,\nwhich is saved.\nZ Series and 2D Projection Image acquires the Z\xa0Series, and generates a\nprojection image; in this case all individual Z plane images as well as the\nprojection are saved. This option is only available if Acquire Time Series is\ncleared and Acquire Z Series is selected in the Acquisition tab.\n2D\nProjection\nImage\nAvailable for all Z Series acquisition options other than Single Plane indicates how\nthe resulting 2D projection image is generated.'),
#  Document(id='a0b9afff-05f6-4bbc-a7e4-37496b905678', metadata={'source': 'ImageXpress Nano User Guide'}, page_content='indicator in the Z series diagram and display its current position in µm. The ruler\nmarkings indicate the distance in µm above and below the Focus position.\nDrag the Top or Bottom flags to manually set the top and bottom positions for\nthe Z series acquisition relative to the Focus position. As you manually adjust\none or both of these values, the MetaXpress Software automatically calculates\nand displays the appropriate values for the # of Steps and the Range. The\nposition in µm to which a flag is moved is temporarily displayed on the flag.\nSelect Center Z Series Around Focus Result to evenly space the Z series planes\nabove and below the Focus position. Now, when you drag a Top or Bottom flag on\nthe Z series diagram to manually set the position for the Z series acquisition, the\nMetaXpress Software automatically moves the other position by exactly the same\ntotal distance in µm.'),
#  Document(id='ebfe7c60-669f-44e0-b2bb-ebfd1f77b0dd', metadata={'source': 'ImageXpress Nano User Guide'}, page_content='ImageXpress Nano System with MetaXpress Software User Guide\n84\n5058342 B\nOptions\nDescription\nLaser with\nZ-offset\nDisplayed as an option only if Enable laser-based focusing is selected on the\nAcquisition tab. If selected, then the Laser-based Focusing is used based on the\nsettings that the Laser Autofocus Wizard calculates, or as configured using\nConfigure Laser Settings on the Acquisition tab. Specify the Post-laser offset\nvalue in µm, or click Calculate Offset to automatically calculate the first (W1)\nwavelength offset.\nCalculate\nOffset icon\n(>)\nClick > to display the options that are used for calculating the post-laser offset\nvalue.\nUse Z stack enables the capture of multiple Z plane images so that you can select\nthe best in-focus plane.\nNote: Without Use Z stack, MetaXpress Software carries out an image autofocus\nand determines the best in-focus plane.\nCustom Range determines the total search range and step size for calculating the\noffset.'),
#  Document(id='59d711e9-1691-40fa-a5d8-3b81316689f9', metadata={'source': 'ImageXpress Nano User Guide'}, page_content='ImageXpress Nano System with MetaXpress Software User Guide\n100\n5058342 B\n4. Select an Acquisition Step for the journal to run.\nFigure 5-27: Plate Acquisition Setup dialog: Journals tab, Acquisition Step Selection\nand Loaded Journal\nOption\nDescription\nBefore each\nimage\nRuns only during the acquisition loop, after the illumination is set and focusing is\ncomplete.\nAfter each\nimage\nRuns only during the acquisition loop, after the shutter is closed and before\nimages are saved.\nBefore\nfocusing\nRuns only during the acquisition loop, just before the focus step begins.\nStart of z\nRuns before a Z series is acquired. The journal runs when the Z motor is at the\nlowest step in the series and before an image is acquired. The journal runs once\nfor each wavelength that is configured to use the Z series.\nEnd of z\nRuns after a Z series acquisition is completed. The journal runs when the Z\nmotor is at the highest step in the series and after any projection images are'),
#  Document(id='a92f5cbf-3106-47cb-b6af-a99fbe22c64b', metadata={'source': 'ImageXpress Nano User Guide'}, page_content='5058342 B\nOctober 2017\nImageXpress®\xa0Nano\xa0\nAutomated Imaging System\nWith MetaXpress Software\nUser Guide'),
#  Document(id='5303e6c9-81ff-459e-95b0-76073f9037c6', metadata={'source': 'ImageXpress Nano User Guide'}, page_content='ImageXpress Nano System with MetaXpress Software User Guide\n50\n5058342 B\nAccessing the Plate Acquisition Setup Dialog\nThe MetaXpress Software main menu includes the Screening menu, which is used specifically\nin the MetaXpress Software for protocol configuration and image acquisition. The Screening\nmenu provides access to all plate configuration dialogs and acquisition-specific dialogs,\nincluding the Plate Acquisition Setup dialog. Figure 5-1 and Figure 5-2 show the options that\nare available from the Screening menu.\nFigure 5-1: Default Screening Menu\nFigure 5-2: Simplified Screening Menu')]

# %%
SYSTEM_PROMPT_TEMPLATE = """You are a helpful AI assistant specialized in answering questions based on provided documentation.
Use the following pieces of context to answer the question at the end.
If you don't know the answer, just say you don't know. Don't try to make up an answer.
{context}   
"""

# %%
def answer_question(question: str, history):
    docs = retriever.invoke(question)
    context = "\n\n".join(doc.page_content for doc in docs)
    system_prompt = SYSTEM_PROMPT_TEMPLATE.format(context=context)
    response = llm.invoke([SystemMessage(content=system_prompt), HumanMessage(content=question)])
    return response.content

# %%
gr.ChatInterface(answer_question).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# Explain how MetaXpress software obtain z-series 2D projection Image.
